# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import dicom

#it is possible that in some installations pyDICOM won't be available in which case you will have to install it through pip

# Get file
RefDs = dicom.read_file('IM_0028.dcm')
ConstPixelDims = (int(RefDs.Rows), int(RefDs.Columns))
ArrayDicom = np.zeros(ConstPixelDims, dtype=RefDs.pixel_array.dtype)
ds = dicom.read_file('IM_0028.dcm')
ArrayDicom[:,:]=ds.pixel_array

#plt.figure()
fig=plt.figure(figsize=(15, 15), dpi= 80, facecolor='w', edgecolor='k')
plt.axes().set_aspect('equal') #this makes the image square
plt.set_cmap(plt.gray()) #grayscale
x=np.arange(RefDs.Rows)
y=np.arange(RefDs.Columns)

plt.pcolormesh(x, y, np.flipud(ArrayDicom[:, :]))
plt.axis([x.min(),x.max(),y.min(),y.max()])
# Out:
# [0, 511, 0, 511]

# %% [markdown]
# ### Answer 2

# %% [markdown]
# (i) I have downloaded MicroDicom software .

# %% [markdown]
# ### Answer 2 (ii)

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

brainpic = novice.open('Question 2 (ii).png')
brainpic.show()

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

brainpic = novice.open('Question 2 (iii).png')
brainpic.show()

# %% [markdown]
# ### Answer 2 - 3

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import dicom


# Get file
RefDs = dicom.read_file('IM_0028.dcm')
# Let's print all the Metadata here
print(RefDs)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M_SE', 'M', 'SE']
# (0008, 0012) Instance Creation Date              DA: '20120101'
# (0008, 0013) Instance Creation Time              TM: '122531'
# (0008, 0014) Instance Creator UID                UI: 1.3.46.670589.11.2501708638.4193405253.2729028880.3304384116
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.46.670589.11.3397498352.605445821.304410668.1378834227
# (0008, 0020) Study Date                          DA: '20110101'
# (0008, 0021) Series Date                         DA: '20110101'
# (0008, 0022) Acquisition Date                    DA: '20110101'
# (0008, 0023) Content Date                        DA: '20110101'
# (0008, 0030) Study Time                          TM: '133916'
# (0008, 0031) Series Time                         TM: '135504.20'
# ...

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import dicom

#it is possible that in some installations pyDICOM won't be available in which case you will have to install it through pip

# Get file
RefDs = dicom.read_file('im140.dcm')
# Let's print all the Metadata here
print(RefDs)
# Out:
# (0008, 0000) Group Length                        UL: 566
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20080603'
# (0008, 0013) Instance Creation Time              TM: '073058'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113619.2.55.3.1284421438.720.1212483672.467.140
# (0008, 0020) Study Date                          DA: '20080603'
# (0008, 0021) Series Date                         DA: '20080603'
# (0008, 0022) Acquisition Date                    DA: '20080603'
# (0008, 0023) Content Date                        DA: '20080603'
# (0008, 0030) Study Time                          TM: '072857'
# (0008, 0031) Series Time                         TM: '073007'
# (0008, 0032) Acquisition Time                    TM: '073017'
# ...

# %% [markdown]
# ### Answer 2- 4

# %% [markdown]
# (A) IM0028 - Phillpis medical systems for IM140 -GE Medical Systems.
#
# (B) IM0028 - Morality is magnetic resonance imaging, IM_140 - CT scan.
#
# (C) IM0028 and IM_140 due to the confiditialty of the patient names has not been given.
#
# (D) IM0028- 12 bits has been used and for IM_140 16 bits has been used.
#
# (E) The three attributes used are :-
# 1. Rescale Intercept
# 2. Reescale Slope
# 3. Rescale Type
#
# (F)Physical distance in the patient between the center of each pixel is being signified by the pixel spacing.
# The direction of the cosines of the first row and the first column with respect tothe patient's location is specified by the image orientation.
# The x, y and z coordinates of the upper left hand corner of the image is being specified by the Image position.
# Slice location gives relative position of the image plane in mm
# Slice thickness gives the nominal slice thickness in mm.
#
# (G) So as to change over the picture data into bone thickness information, we can consider using present CT
# information and get the QCT picture by concentrating on specific territories. The QCT is a 3D technique acquired on a CT
# scanner that gives genuine bone thickness by recognizing low bone mass. We can download a software identifying post processing CT images, after that we can randomly choose the samples which is used to calculate the mean bone density.
